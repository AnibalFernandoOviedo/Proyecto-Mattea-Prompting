# %%
# Instalamos la nueva librería que encontraste
# !pip install -q -U google-genai

print("✅ Librería de última generación instalada.")
# Out:
# ✅ Librería de última generación instalada.

# %%
from google import genai

# CONFIGURACIÓN

API_KEY = "AIzaSyD6I3jXMBoHULzmljL4xA43c0K8Y9qLJnE"
client = genai.Client(api_key=API_KEY)

def poc_mattea_2026(stock_nuevo, presupuesto):
    # TÉCNICA: FEW-SHOT ( éxito real)
    contexto = """
    REFERENCIA DE ÉXITO - MATTEA MAYORISTA:
    - Inversión: $140.000 ARS.
    - Zonas: Buenos Aires, Córdoba, Neuquén.
    - Resultado: +$1.000.000 en ventas y 40 consultas/día.
    """

    # TÉCNICA: CHAIN OF THOUGHT (Pasos lógicos)
    instrucciones = """
    Pasos de análisis:
    1. Evaluar logística desde Posadas, Misiones.
    2. Identificar ciudades clave según el éxito previo.
    3. Redactar anuncio persuasivo para dueños de bazares.
    """

    prompt_final = f"{contexto}\n{instrucciones}\nStock: {stock_nuevo}\nPresupuesto: {presupuesto}"


    response = client.models.generate_content(
        model="gemini-3-flash-preview",
        contents=prompt_final
    )

    return response.text

# --- PRUEBA REAL ---
print("--- EJECUTANDO POC MATTEA (GEMINI 3 FLASH PREVIEW) ---")
try:
    resultado = poc_mattea_2026("40 Termos Media Manija y 30 Mates", "140000")
    print(resultado)
except Exception as e:
    print(f"Error: {e}")
# Out:
# --- EJECUTANDO POC MATTEA (GEMINI 3 FLASH PREVIEW) ---
# Este es el análisis estratégico para replicar el éxito de Mattea Mayorista, adaptado a tu ubicación en **Posadas, Misiones**, con tu stock actual y presupuesto.
#
# ---
#
# ### 1. Evaluación Logística desde Posadas, Misiones
#
# Operar desde Posadas tiene desafíos y oportunidades geográficas:
#
# *   **Fortaleza Local:** Tienes ventaja competitiva en el NEA (Corrientes, Chaco, Formosa) por cercanía y menores costos de envío.
# *   **Transportes Clave:**
#     *   **Crucero del Norte / Via Cargo:** Al ser Misiones la "casa" de varias empresas de transporte, tienes frecuencias diarias hacia Buenos Aires y Rosario.
#     *   **Andreani/Correo Argentino:** Ideales para pedidos más pequeños (combos de 3-5 unidades).
# *   **Estrategia de Costos:** Para competir con mayoristas de Buenos Aires, debes ofrecer un **"Subsidio de Envío"**.
# ...
